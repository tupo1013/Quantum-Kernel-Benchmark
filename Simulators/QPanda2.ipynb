# %% [markdown]
# # Running Quantum Kernel SVM for Binary Classification on Qulacs #

# %% [markdown]
# ## I. Import libraries

# %% [markdown]
# 1. Import classical libraries (for machine learning)

# %%
!"{sys.executable}" -m pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\user\appdata\roaming\python\python39\site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\user\appdata\roaming\python\python39\site-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\appdata\roaming\python\python39\site-packages (from scikit-learn) (3.6.0)

# %%
import sys
sys.path.append("../Help Function")

import make_data
import classical_algo

import time
import tracemalloc
import os
import csv 

import numpy as np
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Import quantum libraries

# %%
from pyqpanda import *
from functools import lru_cache

# %% [markdown]
# ## 2. Self - configure Feature Map

# %% [markdown]
# We will choose ZFeatureMap (PauliFeatureMap with paulis = ['Z'], alpha = 1.0, reps = 1)
#
# The self-configure circuit will be based on circuit from Qiskit

# %%
def ZFeatureMap(x, reps=1):
    n_qubits = len(x)
    qvm = init_quantum_machine(QMachineType.CPU)
    qlist = qvm.qAlloc_many(n_qubits)
    prog = QProg()

    for _ in range(reps):
        for i in range(n_qubits):
            prog.insert(H(qlist[i]))
        for i in range(n_qubits):
            prog.insert(RZ(qlist[i], x[i]))

    finalize(qvm)
    return prog

# %% [markdown]
# ## 3. Hybrid algorithm (classical SVM + quantum kernel)

# %% [markdown]
# 1. Help - function if use inner product to calculate quantum kernel element (running 2 half-circuit)

# %%
def half_circuit(reps, x_tuple):
    x = np.array(x_tuple)
    n_qubits = len(x)

    qvm = init_quantum_machine(QMachineType.CPU)
    qlist = qvm.qAlloc_many(n_qubits)

    prog = QProg()
    for _ in range(reps):
        for i in range(n_qubits):
            prog.insert(H(qlist[i]))
        for i in range(n_qubits):
            prog.insert(RZ(qlist[i], x[i]))

    qvm.run(prog)
    state_vec = qvm.get_qstate()

    qvm.finalize()
    return tuple(state_vec)

# %% [markdown]
# 2. Help - function if DON'T use inner product (running full circuit)

# %%
def full_circuit(reps, first_tuple, sec_tuple):
    x = np.array(first_tuple)
    y = np.array(sec_tuple)
    n_qubits = len(x)

    qvm = init_quantum_machine(QMachineType.CPU)
    qlist = qvm.qAlloc_many(n_qubits)

    prog = QProg()

    for _ in range(reps):
        for i in range(n_qubits):
            prog.insert(H(qlist[i]))
        for i in range(n_qubits):
            prog.insert(RZ(qlist[i], x[i]))

    for _ in range(reps):
        for i in reversed(range(n_qubits)):
            prog.insert(RZ(qlist[i], -y[i]))
        for i in reversed(range(n_qubits)):
            prog.insert(H(qlist[i]))

    qvm.directly_run(prog)
    state_vec = qvm.get_qstate()

    qvm.finalize()
    return tuple(state_vec)

# %% [markdown]
# 3. Compute Quantum Kernel Matrix

# %%
def quantum_kernel(reps, Xa, Xb=None, use_inner_product = False):
    if Xb is None:
        Xb = Xa
    K = np.zeros((len(Xa), len(Xb)), dtype=float)
    if use_inner_product:
        for i, xi in enumerate(Xa):
            si = half_circuit(reps, tuple(np.round(xi, 8)))
            for j, xj in enumerate(Xb):
                sj = half_circuit(reps, tuple(np.round(xj, 8)))
                overlap = np.vdot(si, sj)
                K[i, j] = np.abs(overlap)**2
    else:
        for i, xi in enumerate(Xa):
            for j, xj in enumerate(Xb):
                sij = full_circuit(reps, tuple(np.round(xi, 8)), tuple(np.round(xj, 8)))
                K[i, j] = np.abs(sij[0])**2
    return K

# %% [markdown]
# 4. Compute quantum kernel and training SVM using quantum kernel

# %%
def hybrid_algo(data_train, data_test, label_train, label_test, reps, use_inner_product=False):
    start = time.time()
    tracemalloc.start()
    
    kernel_train = quantum_kernel(reps, data_train, use_inner_product=use_inner_product)
    kernel_test = quantum_kernel(reps, data_test, data_train, use_inner_product=use_inner_product)

    clf_quantum = SVC(kernel='precomputed')
    clf_quantum.fit(kernel_train, label_train)
    y_pred = clf_quantum.predict(kernel_test)
    acc_quantum = accuracy_score(label_test, y_pred)

    _, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    end = time.time()

    return acc_quantum, end - start, peak

# %% [markdown]
# ## 4. Run experiment

# %%
data_size = [10*i for i in range(2,11)]
kernel_option = ["Classical", "ZFeatureMap"]
results = []
rounds = 10

for size in data_size:
    accuracies, times, mems = (np.zeros(len(kernel_option)) for _ in range(3))

    for round in range(rounds):
        x, y = make_data.generate_xor_data(size, noise = 0.1)
        x_train, x_test, y_train, y_test = make_data.engineer_split_set(x,y)

        for idx, option in enumerate(kernel_option):
            if option == "Classical":
                acc, time_exec, peak_mem = classical_algo.classic(x_train, x_test, y_train, y_test)
            else:
                acc, time_exec, peak_mem = hybrid_algo(x_train, x_test, y_train, y_test, reps=1, use_inner_product= False)

            print("\n{} encoding + classical SVM size {}: Round {}".format(option,size, round + 1))
            print("  Accuracy:", acc)
            print("  Execution time (sec):", time_exec)
            print(f"  Peak Memory Usage = {peak_mem/1024/1024:.4f} MB")

            accuracies[idx] += acc
            times[idx] += time_exec
            mems[idx] += peak_mem
    
    accuracies/=rounds
    times/=rounds
    mems/=rounds

    for idx, option in enumerate(kernel_option):
        results.append((size, option, accuracies[idx], times[idx], mems[idx]))
# Out:
# Classical encoding + classical SVM size 20: Round 1
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.0010068416595458984
#   Peak Memory Usage = 0.5717 MB
#
# ZFeatureMap encoding + classical SVM size 20: Round 1
#   Accuracy: 0.5
#   Execution time (sec): 0.18382930755615234
#   Peak Memory Usage = 0.0125 MB
#
# Classical encoding + classical SVM size 20: Round 2
#   Accuracy: 0.5
#   Execution time (sec): 0.001539468765258789
#   Peak Memory Usage = 0.0094 MB
#
# ZFeatureMap encoding + classical SVM size 20: Round 2
#   Accuracy: 0.16666666666666666
#   Execution time (sec): 0.177262544631958
#   Peak Memory Usage = 0.0123 MB
#
# Classical encoding + classical SVM size 20: Round 3
#   Accuracy: 1.0
#   Execution time (sec): 0.006264448165893555
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 20: Round 3
#   Accuracy: 1.0
#   Execution time (sec): 0.17544007301330566
#   Peak Memory Usage = 0.0119 MB
#
# Classical encoding + classical SVM size 20: Round 4
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0096 MB
#
# ZFeatureMap encoding + classical SVM size 20: Round 4
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.16361141204833984
#   Peak Memory Usage = 0.0128 MB
#
# Classical encoding + classical SVM size 20: Round 5
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0096 MB
#
# ZFeatureMap encoding + classical SVM size 20: Round 5
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.16721415519714355
#   Peak Memory Usage = 0.0117 MB
#
# Classical encoding + classical SVM size 20: Round 6
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.005027055740356445
#   Peak Memory Usage = 0.0094 MB
#
# ZFeatureMap encoding + classical SVM size 20: Round 6
#   Accuracy: 0.5
#   Execution time (sec): 0.17916607856750488
#   Peak Memory Usage = 0.0133 MB
#
# Classical encoding + classical SVM size 20: Round 7
#   Accuracy: 0.3333333333333333
#   Execution time (sec): 0.0028405189514160156
#   Peak Memory Usage = 0.0094 MB
#
# ZFeatureMap encoding + classical SVM size 20: Round 7
#   Accuracy: 0.3333333333333333
#   Execution time (sec): 0.16131234169006348
#   Peak Memory Usage = 0.0116 MB
#
# Classical encoding + classical SVM size 20: Round 8
#   Accuracy: 0.6666666666666666
#   Execution time (sec): 0.015756607055664062
#   Peak Memory Usage = 0.0095 MB
#
# ZFeatureMap encoding + classical SVM size 20: Round 8
#   Accuracy: 0.6666666666666666
#   Execution time (sec): 0.16716670989990234
#   Peak Memory Usage = 0.0120 MB
#
# Classical encoding + classical SVM size 20: Round 9
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.016080617904663086
#   Peak Memory Usage = 0.0095 MB
#
# ZFeatureMap encoding + classical SVM size 20: Round 9
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.1659843921661377
#   Peak Memory Usage = 0.0118 MB
#
# Classical encoding + classical SVM size 20: Round 10
#   Accuracy: 0.6666666666666666
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0095 MB
#
# ZFeatureMap encoding + classical SVM size 20: Round 10
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.18123364448547363
#   Peak Memory Usage = 0.0121 MB
#
# Classical encoding + classical SVM size 30: Round 1
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.01894831657409668
#   Peak Memory Usage = 0.0096 MB
#
# ZFeatureMap encoding + classical SVM size 30: Round 1
#   Accuracy: 0.6666666666666666
#   Execution time (sec): 0.3895413875579834
#   Peak Memory Usage = 0.0149 MB
#
# Classical encoding + classical SVM size 30: Round 2
#   Accuracy: 0.6666666666666666
#   Execution time (sec): 0.0050373077392578125
#   Peak Memory Usage = 0.0097 MB
#
# ZFeatureMap encoding + classical SVM size 30: Round 2
#   Accuracy: 0.6666666666666666
#   Execution time (sec): 0.37567710876464844
#   Peak Memory Usage = 0.0149 MB
#
# Classical encoding + classical SVM size 30: Round 3
#   Accuracy: 1.0
#   Execution time (sec): 0.01146078109741211
#   Peak Memory Usage = 0.0097 MB
#
# ZFeatureMap encoding + classical SVM size 30: Round 3
#   Accuracy: 1.0
#   Execution time (sec): 0.39014458656311035
#   Peak Memory Usage = 0.0149 MB
#
# Classical encoding + classical SVM size 30: Round 4
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.009241580963134766
#   Peak Memory Usage = 0.0098 MB
#
# ZFeatureMap encoding + classical SVM size 30: Round 4
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.3839263916015625
#   Peak Memory Usage = 0.0149 MB
#
# Classical encoding + classical SVM size 30: Round 5
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0096 MB
#
# ZFeatureMap encoding + classical SVM size 30: Round 5
#   Accuracy: 0.6666666666666666
#   Execution time (sec): 0.3917670249938965
#   Peak Memory Usage = 0.0148 MB
#
# Classical encoding + classical SVM size 30: Round 6
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.005185842514038086
#   Peak Memory Usage = 0.0097 MB
#
# ZFeatureMap encoding + classical SVM size 30: Round 6
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.40100669860839844
#   Peak Memory Usage = 0.0149 MB
#
# Classical encoding + classical SVM size 30: Round 7
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.005192279815673828
#   Peak Memory Usage = 0.0097 MB
#
# ZFeatureMap encoding + classical SVM size 30: Round 7
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.3777585029602051
#   Peak Memory Usage = 0.0149 MB
#
# Classical encoding + classical SVM size 30: Round 8
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.0052144527435302734
#   Peak Memory Usage = 0.0097 MB
#
# ZFeatureMap encoding + classical SVM size 30: Round 8
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.38648533821105957
#   Peak Memory Usage = 0.0149 MB
#
# Classical encoding + classical SVM size 30: Round 9
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.002165079116821289
#   Peak Memory Usage = 0.0097 MB
#
# ZFeatureMap encoding + classical SVM size 30: Round 9
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.36670446395874023
#   Peak Memory Usage = 0.0149 MB
#
# Classical encoding + classical SVM size 30: Round 10
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.0011546611785888672
#   Peak Memory Usage = 0.0099 MB
#
# ZFeatureMap encoding + classical SVM size 30: Round 10
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.38251209259033203
#   Peak Memory Usage = 0.0150 MB
#
# Classical encoding + classical SVM size 40: Round 1
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 0.005023002624511719
#   Peak Memory Usage = 0.0098 MB
#
# ZFeatureMap encoding + classical SVM size 40: Round 1
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 0.6673030853271484
#   Peak Memory Usage = 0.0187 MB
#
# Classical encoding + classical SVM size 40: Round 2
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.004185199737548828
#   Peak Memory Usage = 0.0098 MB
#
# ZFeatureMap encoding + classical SVM size 40: Round 2
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 0.6682770252227783
#   Peak Memory Usage = 0.0187 MB
#
# Classical encoding + classical SVM size 40: Round 3
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 0.018110990524291992
#   Peak Memory Usage = 0.0098 MB
#
# ZFeatureMap encoding + classical SVM size 40: Round 3
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.6814579963684082
#   Peak Memory Usage = 0.0187 MB
#
# Classical encoding + classical SVM size 40: Round 4
#   Accuracy: 0.75
#   Execution time (sec): 0.004924297332763672
#   Peak Memory Usage = 0.0101 MB
#
# ZFeatureMap encoding + classical SVM size 40: Round 4
#   Accuracy: 0.75
#   Execution time (sec): 0.6599717140197754
#   Peak Memory Usage = 0.0190 MB
#
# Classical encoding + classical SVM size 40: Round 5
#   Accuracy: 0.75
#   Execution time (sec): 0.015099287033081055
#   Peak Memory Usage = 0.0100 MB
#
# ZFeatureMap encoding + classical SVM size 40: Round 5
#   Accuracy: 0.75
#   Execution time (sec): 0.6677114963531494
#   Peak Memory Usage = 0.0187 MB
#
# Classical encoding + classical SVM size 40: Round 6
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0098 MB
#
# ZFeatureMap encoding + classical SVM size 40: Round 6
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.6726000308990479
#   Peak Memory Usage = 0.0187 MB
#
# Classical encoding + classical SVM size 40: Round 7
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 0.004940032958984375
#   Peak Memory Usage = 0.0098 MB
#
# ZFeatureMap encoding + classical SVM size 40: Round 7
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.6984081268310547
#   Peak Memory Usage = 0.0192 MB
#
# Classical encoding + classical SVM size 40: Round 8
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.0024912357330322266
#   Peak Memory Usage = 0.0098 MB
#
# ZFeatureMap encoding + classical SVM size 40: Round 8
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.6866106986999512
#   Peak Memory Usage = 0.0187 MB
#
# Classical encoding + classical SVM size 40: Round 9
#   Accuracy: 0.75
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0098 MB
#
# ZFeatureMap encoding + classical SVM size 40: Round 9
#   Accuracy: 0.75
#   Execution time (sec): 0.6716094017028809
#   Peak Memory Usage = 0.0187 MB
#
# Classical encoding + classical SVM size 40: Round 10
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.005205392837524414
#   Peak Memory Usage = 0.0098 MB
#
# ZFeatureMap encoding + classical SVM size 40: Round 10
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.688201904296875
#   Peak Memory Usage = 0.0187 MB
#
# Classical encoding + classical SVM size 50: Round 1
#   Accuracy: 0.8
#   Execution time (sec): 0.01208353042602539
#   Peak Memory Usage = 0.0100 MB
#
# ZFeatureMap encoding + classical SVM size 50: Round 1
#   Accuracy: 0.8666666666666667
#   Execution time (sec): 1.0437731742858887
#   Peak Memory Usage = 0.0263 MB
#
# Classical encoding + classical SVM size 50: Round 2
#   Accuracy: 0.9333333333333333
#   Execution time (sec): 0.0050201416015625
#   Peak Memory Usage = 0.0101 MB
#
# ZFeatureMap encoding + classical SVM size 50: Round 2
#   Accuracy: 0.9333333333333333
#   Execution time (sec): 1.0529518127441406
#   Peak Memory Usage = 0.0263 MB
#
# Classical encoding + classical SVM size 50: Round 3
#   Accuracy: 0.9333333333333333
#   Execution time (sec): 0.010557174682617188
#   Peak Memory Usage = 0.0101 MB
#
# ZFeatureMap encoding + classical SVM size 50: Round 3
#   Accuracy: 0.9333333333333333
#   Execution time (sec): 1.0498857498168945
#   Peak Memory Usage = 0.0263 MB
#
# Classical encoding + classical SVM size 50: Round 4
#   Accuracy: 0.6666666666666666
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0097 MB
#
# ZFeatureMap encoding + classical SVM size 50: Round 4
#   Accuracy: 0.6
#   Execution time (sec): 1.049985647201538
#   Peak Memory Usage = 0.0263 MB
#
# Classical encoding + classical SVM size 50: Round 5
#   Accuracy: 0.9333333333333333
#   Execution time (sec): 0.017126083374023438
#   Peak Memory Usage = 0.0107 MB
#
# ZFeatureMap encoding + classical SVM size 50: Round 5
#   Accuracy: 0.9333333333333333
#   Execution time (sec): 1.0430586338043213
#   Peak Memory Usage = 0.0263 MB
#
# Classical encoding + classical SVM size 50: Round 6
#   Accuracy: 0.9333333333333333
#   Execution time (sec): 0.0077593326568603516
#   Peak Memory Usage = 0.0099 MB
#
# ZFeatureMap encoding + classical SVM size 50: Round 6
#   Accuracy: 0.9333333333333333
#   Execution time (sec): 1.0427582263946533
#   Peak Memory Usage = 0.0263 MB
#
# Classical encoding + classical SVM size 50: Round 7
#   Accuracy: 0.6
#   Execution time (sec): 0.0053102970123291016
#   Peak Memory Usage = 0.0100 MB
#
# ZFeatureMap encoding + classical SVM size 50: Round 7
#   Accuracy: 0.5333333333333333
#   Execution time (sec): 1.0538504123687744
#   Peak Memory Usage = 0.0263 MB
#
# Classical encoding + classical SVM size 50: Round 8
#   Accuracy: 0.8
#   Execution time (sec): 0.004823446273803711
#   Peak Memory Usage = 0.0132 MB
#
# ZFeatureMap encoding + classical SVM size 50: Round 8
#   Accuracy: 0.8666666666666667
#   Execution time (sec): 1.0542519092559814
#   Peak Memory Usage = 0.0268 MB
#
# Classical encoding + classical SVM size 50: Round 9
#   Accuracy: 1.0
#   Execution time (sec): 0.014600038528442383
#   Peak Memory Usage = 0.0108 MB
#
# ZFeatureMap encoding + classical SVM size 50: Round 9
#   Accuracy: 0.6666666666666666
#   Execution time (sec): 1.0548756122589111
#   Peak Memory Usage = 0.0263 MB
#
# Classical encoding + classical SVM size 50: Round 10
#   Accuracy: 0.6666666666666666
#   Execution time (sec): 0.0051593780517578125
#   Peak Memory Usage = 0.0099 MB
#
# ZFeatureMap encoding + classical SVM size 50: Round 10
#   Accuracy: 0.8666666666666667
#   Execution time (sec): 1.0750834941864014
#   Peak Memory Usage = 0.0263 MB
#
# Classical encoding + classical SVM size 60: Round 1
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.010837078094482422
#   Peak Memory Usage = 0.0101 MB
#
# ZFeatureMap encoding + classical SVM size 60: Round 1
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 1.488037109375
#   Peak Memory Usage = 0.0363 MB
#
# Classical encoding + classical SVM size 60: Round 2
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.01111912727355957
#   Peak Memory Usage = 0.0100 MB
#
# ZFeatureMap encoding + classical SVM size 60: Round 2
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 1.5081470012664795
#   Peak Memory Usage = 0.0363 MB
#
# Classical encoding + classical SVM size 60: Round 3
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.0051119327545166016
#   Peak Memory Usage = 0.0100 MB
#
# ZFeatureMap encoding + classical SVM size 60: Round 3
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 1.5142550468444824
#   Peak Memory Usage = 0.0363 MB
#
# Classical encoding + classical SVM size 60: Round 4
#   Accuracy: 0.9444444444444444
#   Execution time (sec): 0.0050201416015625
#   Peak Memory Usage = 0.0101 MB
#
# ZFeatureMap encoding + classical SVM size 60: Round 4
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 1.4796292781829834
#   Peak Memory Usage = 0.0363 MB
#
# Classical encoding + classical SVM size 60: Round 5
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.0015919208526611328
#   Peak Memory Usage = 0.0101 MB
#
# ZFeatureMap encoding + classical SVM size 60: Round 5
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 1.520979642868042
#   Peak Memory Usage = 0.0367 MB
#
# Classical encoding + classical SVM size 60: Round 6
#   Accuracy: 0.9444444444444444
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0101 MB
#
# ZFeatureMap encoding + classical SVM size 60: Round 6
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 1.500068187713623
#   Peak Memory Usage = 0.0363 MB
#
# Classical encoding + classical SVM size 60: Round 7
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.014518022537231445
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 60: Round 7
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 1.5154850482940674
#   Peak Memory Usage = 0.0363 MB
#
# Classical encoding + classical SVM size 60: Round 8
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.005072355270385742
#   Peak Memory Usage = 0.0101 MB
#
# ZFeatureMap encoding + classical SVM size 60: Round 8
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 1.5118885040283203
#   Peak Memory Usage = 0.0363 MB
#
# Classical encoding + classical SVM size 60: Round 9
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0100 MB
#
# ZFeatureMap encoding + classical SVM size 60: Round 9
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 1.4993276596069336
#   Peak Memory Usage = 0.0363 MB
#
# Classical encoding + classical SVM size 60: Round 10
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.01206207275390625
#   Peak Memory Usage = 0.0102 MB
#
# ZFeatureMap encoding + classical SVM size 60: Round 10
#   Accuracy: 0.9444444444444444
#   Execution time (sec): 1.4998753070831299
#   Peak Memory Usage = 0.0363 MB
#
# Classical encoding + classical SVM size 70: Round 1
#   Accuracy: 0.7619047619047619
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0102 MB
#
# ZFeatureMap encoding + classical SVM size 70: Round 1
#   Accuracy: 0.7619047619047619
#   Execution time (sec): 2.0493974685668945
#   Peak Memory Usage = 0.0481 MB
#
# Classical encoding + classical SVM size 70: Round 2
#   Accuracy: 0.8571428571428571
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 70: Round 2
#   Accuracy: 0.9047619047619048
#   Execution time (sec): 2.049893379211426
#   Peak Memory Usage = 0.0485 MB
#
# Classical encoding + classical SVM size 70: Round 3
#   Accuracy: 0.8571428571428571
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0104 MB
#
# ZFeatureMap encoding + classical SVM size 70: Round 3
#   Accuracy: 0.8571428571428571
#   Execution time (sec): 2.0382540225982666
#   Peak Memory Usage = 0.0481 MB
#
# Classical encoding + classical SVM size 70: Round 4
#   Accuracy: 0.9047619047619048
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 70: Round 4
#   Accuracy: 0.8095238095238095
#   Execution time (sec): 2.050114393234253
#   Peak Memory Usage = 0.0481 MB
#
# Classical encoding + classical SVM size 70: Round 5
#   Accuracy: 1.0
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0104 MB
#
# ZFeatureMap encoding + classical SVM size 70: Round 5
#   Accuracy: 1.0
#   Execution time (sec): 2.070110559463501
#   Peak Memory Usage = 0.0483 MB
#
# Classical encoding + classical SVM size 70: Round 6
#   Accuracy: 0.8095238095238095
#   Execution time (sec): 0.01370382308959961
#   Peak Memory Usage = 0.0102 MB
#
# ZFeatureMap encoding + classical SVM size 70: Round 6
#   Accuracy: 0.8571428571428571
#   Execution time (sec): 2.050060510635376
#   Peak Memory Usage = 0.0485 MB
#
# Classical encoding + classical SVM size 70: Round 7
#   Accuracy: 0.9523809523809523
#   Execution time (sec): 0.016242265701293945
#   Peak Memory Usage = 0.0102 MB
#
# ZFeatureMap encoding + classical SVM size 70: Round 7
#   Accuracy: 0.9523809523809523
#   Execution time (sec): 2.0734410285949707
#   Peak Memory Usage = 0.0481 MB
#
# Classical encoding + classical SVM size 70: Round 8
#   Accuracy: 0.9523809523809523
#   Execution time (sec): 0.006371259689331055
#   Peak Memory Usage = 0.0105 MB
#
# ZFeatureMap encoding + classical SVM size 70: Round 8
#   Accuracy: 0.9523809523809523
#   Execution time (sec): 2.0522618293762207
#   Peak Memory Usage = 0.0481 MB
#
# Classical encoding + classical SVM size 70: Round 9
#   Accuracy: 0.7619047619047619
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0101 MB
#
# ZFeatureMap encoding + classical SVM size 70: Round 9
#   Accuracy: 0.7619047619047619
#   Execution time (sec): 2.050170421600342
#   Peak Memory Usage = 0.0481 MB
#
# Classical encoding + classical SVM size 70: Round 10
#   Accuracy: 0.8095238095238095
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0102 MB
#
# ZFeatureMap encoding + classical SVM size 70: Round 10
#   Accuracy: 0.8571428571428571
#   Execution time (sec): 2.1015520095825195
#   Peak Memory Usage = 0.0481 MB
#
# Classical encoding + classical SVM size 80: Round 1
#   Accuracy: 0.9583333333333334
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 80: Round 1
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 2.6816787719726562
#   Peak Memory Usage = 0.0622 MB
#
# Classical encoding + classical SVM size 80: Round 2
#   Accuracy: 0.875
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 80: Round 2
#   Accuracy: 0.875
#   Execution time (sec): 2.666384696960449
#   Peak Memory Usage = 0.0620 MB
#
# Classical encoding + classical SVM size 80: Round 3
#   Accuracy: 0.9583333333333334
#   Execution time (sec): 0.005175352096557617
#   Peak Memory Usage = 0.0102 MB
#
# ZFeatureMap encoding + classical SVM size 80: Round 3
#   Accuracy: 0.9583333333333334
#   Execution time (sec): 2.728224515914917
#   Peak Memory Usage = 0.0617 MB
#
# Classical encoding + classical SVM size 80: Round 4
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 0.01612234115600586
#   Peak Memory Usage = 0.0105 MB
#
# ZFeatureMap encoding + classical SVM size 80: Round 4
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 2.7206077575683594
#   Peak Memory Usage = 0.0617 MB
#
# Classical encoding + classical SVM size 80: Round 5
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 0.0050356388092041016
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 80: Round 5
#   Accuracy: 0.875
#   Execution time (sec): 2.6883444786071777
#   Peak Memory Usage = 0.0622 MB
#
# Classical encoding + classical SVM size 80: Round 6
#   Accuracy: 0.875
#   Execution time (sec): 0.01653265953063965
#   Peak Memory Usage = 0.0105 MB
#
# ZFeatureMap encoding + classical SVM size 80: Round 6
#   Accuracy: 0.875
#   Execution time (sec): 2.6693050861358643
#   Peak Memory Usage = 0.0617 MB
#
# Classical encoding + classical SVM size 80: Round 7
#   Accuracy: 0.7916666666666666
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0102 MB
#
# ZFeatureMap encoding + classical SVM size 80: Round 7
#   Accuracy: 0.75
#   Execution time (sec): 2.683685064315796
#   Peak Memory Usage = 0.0617 MB
#
# Classical encoding + classical SVM size 80: Round 8
#   Accuracy: 0.75
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 80: Round 8
#   Accuracy: 0.75
#   Execution time (sec): 2.665637731552124
#   Peak Memory Usage = 0.0622 MB
#
# Classical encoding + classical SVM size 80: Round 9
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 80: Round 9
#   Accuracy: 0.9166666666666666
#   Execution time (sec): 2.669391632080078
#   Peak Memory Usage = 0.0617 MB
#
# Classical encoding + classical SVM size 80: Round 10
#   Accuracy: 0.7916666666666666
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0107 MB
#
# ZFeatureMap encoding + classical SVM size 80: Round 10
#   Accuracy: 0.75
#   Execution time (sec): 2.669053792953491
#   Peak Memory Usage = 0.0617 MB
#
# Classical encoding + classical SVM size 90: Round 1
#   Accuracy: 0.8518518518518519
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 90: Round 1
#   Accuracy: 0.8518518518518519
#   Execution time (sec): 3.3812689781188965
#   Peak Memory Usage = 0.0771 MB
#
# Classical encoding + classical SVM size 90: Round 2
#   Accuracy: 0.9259259259259259
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0104 MB
#
# ZFeatureMap encoding + classical SVM size 90: Round 2
#   Accuracy: 0.9259259259259259
#   Execution time (sec): 3.4046242237091064
#   Peak Memory Usage = 0.0776 MB
#
# Classical encoding + classical SVM size 90: Round 3
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.01212000846862793
#   Peak Memory Usage = 0.0104 MB
#
# ZFeatureMap encoding + classical SVM size 90: Round 3
#   Accuracy: 0.7037037037037037
#   Execution time (sec): 3.383429765701294
#   Peak Memory Usage = 0.0771 MB
#
# Classical encoding + classical SVM size 90: Round 4
#   Accuracy: 0.9259259259259259
#   Execution time (sec): 0.016745328903198242
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 90: Round 4
#   Accuracy: 0.9629629629629629
#   Execution time (sec): 3.3662967681884766
#   Peak Memory Usage = 0.0771 MB
#
# Classical encoding + classical SVM size 90: Round 5
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0104 MB
#
# ZFeatureMap encoding + classical SVM size 90: Round 5
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 3.4333527088165283
#   Peak Memory Usage = 0.0776 MB
#
# Classical encoding + classical SVM size 90: Round 6
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0107 MB
#
# ZFeatureMap encoding + classical SVM size 90: Round 6
#   Accuracy: 0.7777777777777778
#   Execution time (sec): 3.3847453594207764
#   Peak Memory Usage = 0.0771 MB
#
# Classical encoding + classical SVM size 90: Round 7
#   Accuracy: 0.8148148148148148
#   Execution time (sec): 0.0045778751373291016
#   Peak Memory Usage = 0.0102 MB
#
# ZFeatureMap encoding + classical SVM size 90: Round 7
#   Accuracy: 0.8518518518518519
#   Execution time (sec): 3.3916893005371094
#   Peak Memory Usage = 0.0771 MB
#
# Classical encoding + classical SVM size 90: Round 8
#   Accuracy: 0.8518518518518519
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0104 MB
#
# ZFeatureMap encoding + classical SVM size 90: Round 8
#   Accuracy: 0.8148148148148148
#   Execution time (sec): 3.4332659244537354
#   Peak Memory Usage = 0.0778 MB
#
# Classical encoding + classical SVM size 90: Round 9
#   Accuracy: 0.8888888888888888
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0104 MB
#
# ZFeatureMap encoding + classical SVM size 90: Round 9
#   Accuracy: 0.8518518518518519
#   Execution time (sec): 3.3999288082122803
#   Peak Memory Usage = 0.0771 MB
#
# Classical encoding + classical SVM size 90: Round 10
#   Accuracy: 0.9629629629629629
#   Execution time (sec): 0.0050885677337646484
#   Peak Memory Usage = 0.0103 MB
#
# ZFeatureMap encoding + classical SVM size 90: Round 10
#   Accuracy: 0.9259259259259259
#   Execution time (sec): 3.3628642559051514
#   Peak Memory Usage = 0.0771 MB
#
# Classical encoding + classical SVM size 100: Round 1
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.004107475280761719
#   Peak Memory Usage = 0.0105 MB
#
# ZFeatureMap encoding + classical SVM size 100: Round 1
#   Accuracy: 0.9
#   Execution time (sec): 4.178992509841919
#   Peak Memory Usage = 0.0948 MB
#
# Classical encoding + classical SVM size 100: Round 2
#   Accuracy: 0.8666666666666667
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0104 MB
#
# ZFeatureMap encoding + classical SVM size 100: Round 2
#   Accuracy: 0.8666666666666667
#   Execution time (sec): 4.152152061462402
#   Peak Memory Usage = 0.0944 MB
#
# Classical encoding + classical SVM size 100: Round 3
#   Accuracy: 0.8666666666666667
#   Execution time (sec): 0.013662099838256836
#   Peak Memory Usage = 0.0118 MB
#
# ZFeatureMap encoding + classical SVM size 100: Round 3
#   Accuracy: 0.7666666666666667
#   Execution time (sec): 4.254518747329712
#   Peak Memory Usage = 0.0948 MB
#
# Classical encoding + classical SVM size 100: Round 4
#   Accuracy: 0.9
#   Execution time (sec): 0.005142688751220703
#   Peak Memory Usage = 0.0106 MB
#
# ZFeatureMap encoding + classical SVM size 100: Round 4
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 4.237606525421143
#   Peak Memory Usage = 0.0944 MB
#
# Classical encoding + classical SVM size 100: Round 5
#   Accuracy: 0.8666666666666667
#   Execution time (sec): 0.015218257904052734
#   Peak Memory Usage = 0.0105 MB
#
# ZFeatureMap encoding + classical SVM size 100: Round 5
#   Accuracy: 0.9
#   Execution time (sec): 4.201246023178101
#   Peak Memory Usage = 0.0950 MB
#
# Classical encoding + classical SVM size 100: Round 6
#   Accuracy: 0.8
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0105 MB
#
# ZFeatureMap encoding + classical SVM size 100: Round 6
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 4.268631458282471
#   Peak Memory Usage = 0.0944 MB
#
# Classical encoding + classical SVM size 100: Round 7
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0106 MB
#
# ZFeatureMap encoding + classical SVM size 100: Round 7
#   Accuracy: 0.7333333333333333
#   Execution time (sec): 4.214465618133545
#   Peak Memory Usage = 0.0944 MB
#
# Classical encoding + classical SVM size 100: Round 8
#   Accuracy: 0.9666666666666667
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0106 MB
#
# ZFeatureMap encoding + classical SVM size 100: Round 8
#   Accuracy: 0.9333333333333333
#   Execution time (sec): 4.216238737106323
#   Peak Memory Usage = 0.0948 MB
#
# Classical encoding + classical SVM size 100: Round 9
#   Accuracy: 0.9666666666666667
#   Execution time (sec): 0.0
#   Peak Memory Usage = 0.0106 MB
#
# ZFeatureMap encoding + classical SVM size 100: Round 9
#   Accuracy: 0.9333333333333333
#   Execution time (sec): 4.245648622512817
#   Peak Memory Usage = 0.0944 MB
#
# Classical encoding + classical SVM size 100: Round 10
#   Accuracy: 0.8333333333333334
#   Execution time (sec): 0.0058596134185791016
#   Peak Memory Usage = 0.0109 MB
#
# ZFeatureMap encoding + classical SVM size 100: Round 10
#   Accuracy: 0.7
#   Execution time (sec): 4.229981184005737
#   Peak Memory Usage = 0.0948 MB

# %% [markdown]
# ## V. Graph

# %%
# %matplotlib inline
data_sizes, encodings, accuracies, times, mems = zip(*results)
unique_encodings = list(dict.fromkeys(encodings))  

plt.figure(figsize=(8,6))

for option in unique_encodings:
    x_vals = [s for s, e in zip(data_sizes, encodings) if e == option]
    y_vals = [a for a, e in zip(accuracies, encodings) if e == option]

    plt.plot(x_vals, y_vals, 'o-', label=option)

plt.xlabel("Data Sizes")
plt.ylabel("Accuracy")
plt.title("Data Sizes vs Accuracy (Classical & Quantum Encodings)")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Store Data

# %%
platform = "qpanda2"
record_folder = "../Record Data"

os.makedirs(record_folder, exist_ok=True)

with open(os.path.join(record_folder, "time_executions.csv"), mode="a", newline="") as file:
    writer = csv.writer(file)
    for i, t in enumerate(times):
        if i%2 !=0: writer.writerow([platform, data_sizes[i], t])

with open(os.path.join(record_folder, "memory_usage.csv"), mode="a", newline="") as file:
    writer = csv.writer(file)
    for i, t in enumerate(mems):
        if i%2 !=0: writer.writerow([platform, data_sizes[i], t/1024/1024])
